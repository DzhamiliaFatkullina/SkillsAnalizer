# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time
import random
from typing import List, Dict, Optional

# %%
BASE_URL = "https://hh.ru"
SEARCH_URL = "https://hh.ru/search/vacancy?text=Программист&professional_role=96&hhtmFrom&"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}
MAX_PAGES = 40 # Number of search result pages to scrape
DELAY = random.uniform(1, 3)  # Delay between requests to avoid being blocked

# %%
def get_page(url: str) -> Optional[BeautifulSoup]:
    """
    Fetch a webpage and return its BeautifulSoup object.
    
    Args:
        url: URL of the page to fetch
        
    Returns:
        BeautifulSoup object if successful, None otherwise
    """
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        return BeautifulSoup(response.text, 'html.parser')
    except requests.exceptions.RequestException as e:
        print(f"Error fetching page {url}: {e}")
        return None

# %%
def extract_vacancy_links_from_page(soup: BeautifulSoup) -> List[str]:
    """
    Extract vacancy links from a single search results page.
    
    Args:
        soup: BeautifulSoup object of the search results page
        
    Returns:
        List of vacancy URLs
    """
    links = []
    vacancy_blocks = soup.find_all('div', class_='vacancy-info--ieHKDTkezpEj0Gsx')
    
    for block in vacancy_blocks:
        link_tag = block.find('a', {
            'data-qa': 'serp-item__title',
            'class': lambda x: x and 'magritte-link___' in x
        })
        if link_tag and link_tag.get('href'):
            # Ensure the URL is absolute
            absolute_url = urljoin(BASE_URL, link_tag['href'].split('?')[0])
            links.append(absolute_url)
    
    return links

# %%
def get_all_vacancy_links() -> List[str]:
    """
    Get all vacancy links from all search result pages.
    
    Returns:
        List of all vacancy URLs found
    """
    all_links = []
    # Search from Moscow, St-Petesburg and Kazan
    for area in [1, 2, 88]:
        print(f"Searching area {area}...")
        for page in range(MAX_PAGES):
            if page%10 == 0:
                print(f"Processing search page {page + 1} of {MAX_PAGES}")
            page_url = f"{SEARCH_URL}&page={page}&area={area}=vacancy_search_list"
            soup = get_page(page_url)
            
            if not soup:
                # print(f"Failed to process page {page + 1}, skipping...")
                continue
            
            page_links = extract_vacancy_links_from_page(soup)
            if not page_links:
                # print(f"No links found on page {page + 1}, stopping pagination.")
                break
                
            all_links.extend(page_links)
            # print(f"Found {len(page_links)} links on this page (total: {len(all_links)})")
            
            # Respectful delay between requests
            time.sleep(DELAY)
    
    return all_links

# %%
print("\nStep 1: Collecting vacancy links from search results...")
vacancy_links = get_all_vacancy_links()
# Out:
# Step 1: Collecting vacancy links from search results...
# Searching area 1...
# Processing search page 1 of 40
# Processing search page 11 of 40
# Processing search page 21 of 40
# Processing search page 31 of 40
# Searching area 2...
# Processing search page 1 of 40
# Processing search page 11 of 40
# Processing search page 21 of 40
# Processing search page 31 of 40
# Searching area 88...
# Processing search page 1 of 40
# Processing search page 11 of 40
# Processing search page 21 of 40
# Processing search page 31 of 40

# %%
print(len(vacancy_links))

# %%
# Should be written only once

# with open('links.txt', 'w') as f:
#     for link in vacancy_links:
#         f.write(f"{link}\n")

# %%
def extract_key_skills(soup):
    """
    Extracts the list of key skills from the HTML content of a job posting.
    
    Args:
        html_content (str): HTML content of the job posting
        
    Returns:
        list: List of key skills found in the posting
    """
    # soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the skills section by looking for the unordered list with the specific class
    skills_section = soup.find('ul', class_='vacancy-skill-list--JsTYRZ5o6dsoavK7')
    
    if not skills_section:
        return []
    
    # Extract all skill items
    skill_items = skills_section.find_all('li', attrs={'data-qa': 'skills-element'})
    
    skills = []
    for item in skill_items:
        # Find the div with the skill label
        label_div = item.find('div', class_='magritte-tag__label___YHV-o_3-1-13')
        if label_div:
            skills.append(label_div.get_text(strip=True))
    
    return skills


def process_vacancy_links(vacancy_links: List[str]) -> List[List[str]]:
    """
    Process each vacancy link to extract key skills.
    
    Args:
        vacancy_links: List of vacancy URLs to process
        
    Returns:
        2D array of skills (list of lists), where each inner list contains skills for one vacancy
    """
    all_skills = []
    
    for i, link in enumerate(vacancy_links, 1):
        if i % 10 == 0:
            print(f"Prossesing {i} link...")
        # print(f"Processing vacancy {i} of {len(vacancy_links)}: {link}")
        if link == "https://adsrv.hh.ru/click":
            continue

        soup = get_page(link)
        
        if not soup:
            # print(f"Failed to process vacancy {link}, skipping...")
            all_skills.append([])  # Add empty list for consistency
            continue
        
        skills = extract_key_skills(soup)
        all_skills.append(skills)
        # print(f"Found {len(skills)} skills for this vacancy")
        
        # Respectful delay between requests
        time.sleep(DELAY)
    
    return all_skills

# %%
print(len(vacancy_links))
# Out:
# 2400

# %%
print("\nStep 2: Extracting key skills from each vacancy...")
vacancy_skills = process_vacancy_links(vacancy_links)
# Out:
# Step 2: Extracting key skills from each vacancy...
# Prossesing 10 link...
# Prossesing 20 link...
# Prossesing 30 link...
# Prossesing 40 link...
# Prossesing 50 link...
# Prossesing 60 link...
# Prossesing 70 link...
# Prossesing 80 link...
# Prossesing 90 link...
# Prossesing 100 link...
# Prossesing 110 link...
# Prossesing 120 link...
# Prossesing 130 link...
# Prossesing 140 link...
# Prossesing 150 link...
# Prossesing 160 link...
# Prossesing 170 link...
# Prossesing 180 link...
# Prossesing 190 link...
# Prossesing 200 link...
# Prossesing 210 link...
# Prossesing 220 link...
# Prossesing 230 link...
# Prossesing 240 link...
# Prossesing 250 link...
# Prossesing 260 link...
# Prossesing 270 link...
# Prossesing 280 link...
# Prossesing 290 link...
# Prossesing 300 link...
# Prossesing 310 link...
# Prossesing 320 link...
# Prossesing 330 link...
# Prossesing 340 link...
# Prossesing 350 link...
# Prossesing 360 link...
# Prossesing 370 link...
# Prossesing 380 link...
# Prossesing 390 link...
# Prossesing 400 link...
# Prossesing 410 link...
# Prossesing 420 link...
# Prossesing 430 link...
# Prossesing 440 link...
# Prossesing 450 link...
# Prossesing 460 link...
# Prossesing 470 link...
# Prossesing 480 link...
# Prossesing 490 link...
# Prossesing 500 link...
# Prossesing 510 link...
# Prossesing 520 link...
# Prossesing 530 link...
# Prossesing 540 link...
# Prossesing 550 link...
# Prossesing 560 link...
# Prossesing 570 link...
# Prossesing 580 link...
# Prossesing 590 link...
# Prossesing 600 link...
# Prossesing 610 link...
# Prossesing 620 link...
# Prossesing 630 link...
# Prossesing 640 link...
# Prossesing 650 link...
# Prossesing 660 link...
# Prossesing 670 link...
# Prossesing 680 link...
# Error fetching page https://hh.ru/vacancy/118952928: HTTPSConnectionPool(host='hh.ru', port=443): Max retries exceeded with url: /vacancy/118952928 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
# Prossesing 690 link...
# Prossesing 700 link...
# Prossesing 710 link...
# Prossesing 720 link...
# Prossesing 730 link...
# Prossesing 740 link...
# Prossesing 750 link...
# Prossesing 760 link...
# Prossesing 770 link...
# Prossesing 780 link...
# Prossesing 790 link...
# Prossesing 800 link...
# Prossesing 810 link...
# Prossesing 820 link...
# Prossesing 830 link...
# Prossesing 840 link...
# Prossesing 850 link...
# Prossesing 860 link...
# Prossesing 870 link...
# Prossesing 880 link...
# Prossesing 890 link...
# Prossesing 900 link...
# Prossesing 910 link...
# Prossesing 920 link...
# Prossesing 930 link...
# Prossesing 940 link...
# Prossesing 950 link...
# Prossesing 960 link...
# Prossesing 970 link...
# Prossesing 980 link...
# Prossesing 990 link...
# Prossesing 1000 link...
# Prossesing 1010 link...
# Prossesing 1020 link...
# Prossesing 1030 link...
# Prossesing 1040 link...
# Prossesing 1050 link...
# Prossesing 1060 link...
# Prossesing 1070 link...
# Prossesing 1080 link...
# Prossesing 1090 link...
# Prossesing 1100 link...
# Prossesing 1110 link...
# Prossesing 1120 link...
# Error fetching page https://hh.ru/vacancy/119553901: 403 Client Error: Forbidden for url: https://hh.ru/vacancy/119553901
# Prossesing 1130 link...
# Prossesing 1140 link...
# Prossesing 1150 link...
# Prossesing 1160 link...
# Error fetching page https://hh.ru/vacancy/119907166: Response ended prematurely
# Prossesing 1170 link...
# Prossesing 1180 link...
# Prossesing 1190 link...
# Prossesing 1200 link...
# Prossesing 1210 link...
# Prossesing 1220 link...
# Prossesing 1230 link...
# Prossesing 1240 link...
# Prossesing 1250 link...
# Prossesing 1260 link...
# Prossesing 1270 link...
# Error fetching page https://hh.ru/vacancy/119927787: HTTPSConnectionPool(host='hh.ru', port=443): Max retries exceeded with url: /vacancy/119927787 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Error fetching page https://hh.ru/vacancy/116165831: HTTPSConnectionPool(host='hh.ru', port=443): Max retries exceeded with url: /vacancy/116165831 (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
# Prossesing 1280 link...
# Error fetching page https://hh.ru/vacancy/119926741: HTTPSConnectionPool(host='hh.ru', port=443): Max retries exceeded with url: /vacancy/119926741 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Prossesing 1290 link...
# Prossesing 1300 link...
# Prossesing 1310 link...
# Prossesing 1320 link...
# Prossesing 1330 link...
# Prossesing 1340 link...
# Error fetching page https://hh.ru/vacancy/119909409: HTTPSConnectionPool(host='hh.ru', port=443): Max retries exceeded with url: /vacancy/119909409 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Prossesing 1350 link...
# Prossesing 1360 link...
# Prossesing 1370 link...
# Prossesing 1380 link...
# Prossesing 1390 link...
# Prossesing 1400 link...
# Prossesing 1410 link...
# Prossesing 1420 link...
# Prossesing 1430 link...
# Prossesing 1440 link...
# Prossesing 1450 link...
# Prossesing 1460 link...
# Prossesing 1470 link...
# Error fetching page https://hh.ru/vacancy/119924700: 403 Client Error: Forbidden for url: https://hh.ru/vacancy/119924700
# Prossesing 1480 link...
# Prossesing 1490 link...
# Error fetching page https://hh.ru/vacancy/119650341: 403 Client Error: Forbidden for url: https://hh.ru/vacancy/119650341
# Prossesing 1500 link...
# Prossesing 1510 link...
# Prossesing 1520 link...
# Prossesing 1530 link...
# Prossesing 1540 link...
# Prossesing 1550 link...
# Prossesing 1560 link...
# Prossesing 1570 link...
# Prossesing 1580 link...
# Prossesing 1590 link...
# Prossesing 1600 link...
# Prossesing 1610 link...
# Prossesing 1620 link...
# Prossesing 1630 link...
# Prossesing 1640 link...
# Prossesing 1650 link...
# Prossesing 1660 link...
# Prossesing 1670 link...
# Prossesing 1680 link...
# Prossesing 1690 link...
# Prossesing 1700 link...
# Prossesing 1710 link...
# Prossesing 1720 link...
# Prossesing 1730 link...
# Prossesing 1740 link...
# Prossesing 1750 link...
# Prossesing 1760 link...
# Prossesing 1770 link...
# Prossesing 1780 link...
# Prossesing 1790 link...
# Error fetching page https://hh.ru/vacancy/103208576: HTTPSConnectionPool(host='hh.ru', port=443): Max retries exceeded with url: /vacancy/103208576 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Prossesing 1800 link...
# Prossesing 1810 link...
# Prossesing 1820 link...
# Prossesing 1830 link...
# Prossesing 1840 link...
# Prossesing 1850 link...
# Prossesing 1860 link...
# Prossesing 1870 link...
# Prossesing 1880 link...
# Prossesing 1890 link...
# Prossesing 1900 link...
# Prossesing 1910 link...
# Prossesing 1920 link...
# Error fetching page https://hh.ru/vacancy/119553901: 403 Client Error: Forbidden for url: https://hh.ru/vacancy/119553901
# Prossesing 1930 link...
# Prossesing 1940 link...
# Prossesing 1950 link...
# Prossesing 1960 link...
# Prossesing 1970 link...
# Prossesing 1980 link...
# Prossesing 1990 link...
# Prossesing 2000 link...
# Prossesing 2010 link...
# Prossesing 2020 link...
# Prossesing 2030 link...
# Prossesing 2040 link...
# Prossesing 2050 link...
# Prossesing 2060 link...
# Prossesing 2070 link...
# Prossesing 2080 link...
# Prossesing 2090 link...
# Prossesing 2100 link...
# Prossesing 2110 link...
# Prossesing 2120 link...
# Prossesing 2130 link...
# Prossesing 2140 link...
# Prossesing 2150 link...
# Prossesing 2160 link...
# Prossesing 2170 link...
# Prossesing 2180 link...
# Prossesing 2190 link...
# Prossesing 2200 link...
# Prossesing 2210 link...
# Prossesing 2220 link...
# Prossesing 2230 link...
# Prossesing 2240 link...
# Prossesing 2250 link...
# Prossesing 2260 link...
# Prossesing 2270 link...
# Prossesing 2280 link...
# Error fetching page https://hh.ru/vacancy/119924700: 403 Client Error: Forbidden for url: https://hh.ru/vacancy/119924700
# Prossesing 2290 link...
# Prossesing 2300 link...
# Error fetching page https://hh.ru/vacancy/119650341: 403 Client Error: Forbidden for url: https://hh.ru/vacancy/119650341
# Prossesing 2310 link...
# Prossesing 2320 link...
# Prossesing 2330 link...
# Prossesing 2340 link...
# Prossesing 2350 link...
# Prossesing 2360 link...
# Prossesing 2370 link...
# Prossesing 2380 link...
# Prossesing 2390 link...
# Prossesing 2400 link...

# %%
print(vacancy_skills)
# Out:
# [[], ['PHP', 'PHP 7.4-8', 'Nginx', 'MySQL', 'PostgreSQL', 'REST API'], [], ['Администрирование серверов Windows', 'Linux', 'Ремонт ПК', 'Администрирование сетевого оборудования', 'Windows 7'], ['Точность и внимательность к деталям', 'Cистемы управления базами данных', 'MS Dos', 'Компьютер', 'Знание компьютера'], ['Умение работать в команде', 'Анализ данных', 'Техническая документация', 'Навыки составления отчетности'], [], ['PHP', 'Git', 'jQuery', 'CSS3', 'HTML5', 'Ajax', '1С-Битрикс'], [], [], [], ['1C: ERP', 'Оптимизация кода', 'Написание инструкций', 'ERP-системы на базе 1С'], ['ООП', 'MS SQL', 'Visual Studio C#', 'Design Patterns', 'С#'], ['Работа в команде'], ['SQL', 'Delphi', 'C#'], ['IDE Lazarus', 'C++', 'Разработка программного обеспечения для Linux', 'Разработка программного обеспечения для Windows', 'Python', 'Английский\xa0— A2 — Элементарный'], ['C++', 'Python', 'HTML', 'MS Visual Studio', 'Luo'], [], ['SQL', 'JavaScript', 'Кроссбраузерное тестирование', 'Sanity-тестирование', 'Рефакторинг кода', 'Yii', 'Системная интеграция', 'PHP', '.NET Framework', 'Английский\xa0— B2 — Средне-продвинутый'], [], [], [], [], ['1С программирование', '1С: Бухгалтерия', '1С: Управление Торговлей'], ['SQL', 'Java', 'Работа с базами данных', 'JavaScript'], [], ['1С: Предприятие 8', 'Создание конфигурации 1С', 'Техническая поддержка', 'Работа с базами данных', '1С: Управление нашей фирмой'], [], [], [], ['1С: Управление Торговлей', '1С: Бухгалтерия', '1С: Комплексная автоматизация', '1С: Управление Производственным Предприятием', '1С программирование'], ['1С: Управление Торговлей', '1С: Бухгалтерия', '1С: Управление Производственным Предприятием', '1С: Зарплата и кадры', 'Автоматизация процессов', 'ERP-системы на базе 1С', '1С программирование'], [], [], ['1С: Предприятие 8', '1С: Бухгалтерия', '1С: Зарплата и кадры'], ['1С: Документооборот', '1С программирование', '1С: Управление Торговлей', '1С: Производство', 'Терминалы Сбора Данных', '1С: Зарплата и управление персоналом', '1C Предприятие', 'Transact-SQL', 'JSON', '1C ERP'], [], ['MS SQL', '1С: Предприятие 8', 'Работа с базами данных', '1С программирование'], ['АСУ ТП', 'CODESYS', 'Пуско-наладочные работы', 'Чтение электрических схем'], ['1С программирование', 'Базы данных', 'Работа с базами данных', 'Работа с большим объемом информации', 'Поиск информации в интернет'], ['Разработка инструкций', '1С: Документооборот', 'Проведение тестирований', 'Продвинутый пользователь ПК', 'Обучение пользователей'], ['1С программирование', 'Конфигурационное тестирование', 'Автоматизация процессов', '1C: ERP', 'Обновление конфигурации 1С', 'Оптимизация кода', 'Резервное копирование', 'Разработка ПО', 'Работа с базами данных', 'Системная интеграция'], ['1С программирование', '1С'], ['SCADA', 'АСУ ТП', 'TCP/IP'], ['1С программирование'], ['1С программирование', '1С: Управление Торговлей', 'ERP', '1С: Розница'], ['C++', 'Linux', 'Python', 'C++17/20'], [], ['PHP', 'SQL', 'MySQL', 'API', 'Laravel', 'Django'], ['1С: Предприятие 8', '1С: Бухгалтерия', 'СКД', 'HTTP-сервис', 'WEB-сервис'], ['1С: Предприятие 8', 'СКД', 'HTTP-сервис', 'WEB-сервис', 'Системная интеграция'], [], [], ['Java', 'HTML', 'Администрирование сайтов', 'Поиск информации в интернет', 'MS Visual C++'], [], ['1С программирование', '1С: Предприятие 8', 'ERP-системы на базе 1С'], ['1С: Предприятие 8', '1С: Документооборот', '1С: Бухгалтерия', 'Обновление конфигурации 1С', '1С программирование', 'ERP-системы на базе 1С', '1С: Управление Производственным Предприятием'], [], ['PHP', 'MySQL', 'HTML', 'CSS', 'CMS Wordpress', 'SQL', 'Веб-программирование', 'CMS ModX', 'CMS NetCat', 'API', 'Frontend', 'Backend', 'Верстка'], ['Git', 'SQL', 'PostgreSQL', 'Linux', 'TypeScript', 'REST API', 'Docker', 'GraphQL', 'Redis', 'gRPC', 'VueJS', 'CSS', 'HTML'], ['Java', 'Spring Framework'], [], [], [], ['Работа с базами данных', '1С программирование', '1С: Бухгалтерия', '1С: Зарплата и кадры', 'Работа с большим объемом информации'], ['Java', 'Spring Framework' ...

# %%
vacancy_skills = [skills for skills in vacancy_skills if skills != []]
print(vacancy_skills)
print(f"There are {len(vacancy_skills)} pages with skills needed info")
# Out:
# [['PHP', 'PHP 7.4-8', 'Nginx', 'MySQL', 'PostgreSQL', 'REST API'], ['Администрирование серверов Windows', 'Linux', 'Ремонт ПК', 'Администрирование сетевого оборудования', 'Windows 7'], ['Точность и внимательность к деталям', 'Cистемы управления базами данных', 'MS Dos', 'Компьютер', 'Знание компьютера'], ['Умение работать в команде', 'Анализ данных', 'Техническая документация', 'Навыки составления отчетности'], ['PHP', 'Git', 'jQuery', 'CSS3', 'HTML5', 'Ajax', '1С-Битрикс'], ['1C: ERP', 'Оптимизация кода', 'Написание инструкций', 'ERP-системы на базе 1С'], ['ООП', 'MS SQL', 'Visual Studio C#', 'Design Patterns', 'С#'], ['Работа в команде'], ['SQL', 'Delphi', 'C#'], ['IDE Lazarus', 'C++', 'Разработка программного обеспечения для Linux', 'Разработка программного обеспечения для Windows', 'Python', 'Английский\xa0— A2 — Элементарный'], ['C++', 'Python', 'HTML', 'MS Visual Studio', 'Luo'], ['SQL', 'JavaScript', 'Кроссбраузерное тестирование', 'Sanity-тестирование', 'Рефакторинг кода', 'Yii', 'Системная интеграция', 'PHP', '.NET Framework', 'Английский\xa0— B2 — Средне-продвинутый'], ['1С программирование', '1С: Бухгалтерия', '1С: Управление Торговлей'], ['SQL', 'Java', 'Работа с базами данных', 'JavaScript'], ['1С: Предприятие 8', 'Создание конфигурации 1С', 'Техническая поддержка', 'Работа с базами данных', '1С: Управление нашей фирмой'], ['1С: Управление Торговлей', '1С: Бухгалтерия', '1С: Комплексная автоматизация', '1С: Управление Производственным Предприятием', '1С программирование'], ['1С: Управление Торговлей', '1С: Бухгалтерия', '1С: Управление Производственным Предприятием', '1С: Зарплата и кадры', 'Автоматизация процессов', 'ERP-системы на базе 1С', '1С программирование'], ['1С: Предприятие 8', '1С: Бухгалтерия', '1С: Зарплата и кадры'], ['1С: Документооборот', '1С программирование', '1С: Управление Торговлей', '1С: Производство', 'Терминалы Сбора Данных', '1С: Зарплата и управление персоналом', '1C Предприятие', 'Transact-SQL', 'JSON', '1C ERP'], ['MS SQL', '1С: Предприятие 8', 'Работа с базами данных', '1С программирование'], ['АСУ ТП', 'CODESYS', 'Пуско-наладочные работы', 'Чтение электрических схем'], ['1С программирование', 'Базы данных', 'Работа с базами данных', 'Работа с большим объемом информации', 'Поиск информации в интернет'], ['Разработка инструкций', '1С: Документооборот', 'Проведение тестирований', 'Продвинутый пользователь ПК', 'Обучение пользователей'], ['1С программирование', 'Конфигурационное тестирование', 'Автоматизация процессов', '1C: ERP', 'Обновление конфигурации 1С', 'Оптимизация кода', 'Резервное копирование', 'Разработка ПО', 'Работа с базами данных', 'Системная интеграция'], ['1С программирование', '1С'], ['SCADA', 'АСУ ТП', 'TCP/IP'], ['1С программирование'], ['1С программирование', '1С: Управление Торговлей', 'ERP', '1С: Розница'], ['C++', 'Linux', 'Python', 'C++17/20'], ['PHP', 'SQL', 'MySQL', 'API', 'Laravel', 'Django'], ['1С: Предприятие 8', '1С: Бухгалтерия', 'СКД', 'HTTP-сервис', 'WEB-сервис'], ['1С: Предприятие 8', 'СКД', 'HTTP-сервис', 'WEB-сервис', 'Системная интеграция'], ['Java', 'HTML', 'Администрирование сайтов', 'Поиск информации в интернет', 'MS Visual C++'], ['1С программирование', '1С: Предприятие 8', 'ERP-системы на базе 1С'], ['1С: Предприятие 8', '1С: Документооборот', '1С: Бухгалтерия', 'Обновление конфигурации 1С', '1С программирование', 'ERP-системы на базе 1С', '1С: Управление Производственным Предприятием'], ['PHP', 'MySQL', 'HTML', 'CSS', 'CMS Wordpress', 'SQL', 'Веб-программирование', 'CMS ModX', 'CMS NetCat', 'API', 'Frontend', 'Backend', 'Верстка'], ['Git', 'SQL', 'PostgreSQL', 'Linux', 'TypeScript', 'REST API', 'Docker', 'GraphQL', 'Redis', 'gRPC', 'VueJS', 'CSS', 'HTML'], ['Java', 'Spring Framework'], ['Работа с базами данных', '1С программирование', '1С: Бухгалтерия', '1С: Зарплата и кадры', 'Работа с большим объемом информации'], ['Java', 'Spring Framework', 'Hibernate', 'SQL', 'PostgreSQL', 'ORACLE', 'Gradle', 'Apache Kafka', 'RabbitMQ', 'Русский\xa0— C1 — П ...
# There are 1617 pages with skills needed info

# %%
# Should be executed only once

# with open('skills.txt', 'w') as f:
#     for skills in vacancy_skills:
#         f.write(f"{skills}\n")

# %%
from collections import defaultdict

def count_skills(skills_lists):
    skill_counts = defaultdict(int)
    
    for sublist in skills_lists:
        for skill in sublist:
            # Clean up the skill name (remove extra whitespace, normalize variations)
            cleaned_skill = skill.strip().replace('\xa0', ' ')  # Handle non-breaking spaces
            skill_counts[cleaned_skill] += 1
    
    return dict(skill_counts)

skill_counts = count_skills(vacancy_skills)

# Print sorted by count (descending)
for skill, count in sorted(skill_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"{skill}: {count}")
# Out:
# 1С программирование: 423
# Git: 272
# 1С: Предприятие 8: 226
# PostgreSQL: 202
# SQL: 190
# PHP: 186
# 1С: Бухгалтерия: 178
# JavaScript: 168
# C++: 148
# Linux: 145
# 1С: Управление Торговлей: 133
# MySQL: 128
# Обновление конфигурации 1С: 127
# Python: 126
# HTML: 105
# 1С: Зарплата и управление персоналом: 101
# 1С: Документооборот: 97
# Docker: 95
# Java: 93
# ERP-системы на базе 1С: 88
# TypeScript: 80
# REST API: 71
# CSS: 71
# ООП: 70
# 1С: Управление Производственным Предприятием: 69
# Автоматизация процессов: 67
# MS SQL: 66
# Разработка ПО: 63
# React: 63
# 1C: ERP: 61
# C#: 58
# АСУ ТП: 58
# C/C++: 58
# 1С: Предприятие: 57
# Создание конфигурации 1С: 56
# 1С: Зарплата и кадры: 54
# Английский — B1 — Средний: 54
# 1С: 53
# 1С-Битрикс: 52
# Работа в команде: 52
# 1С: Комплексная автоматизация: 51
# Laravel: 51
# Английский язык: 51
# Оптимизация кода: 50
# Redis: 49
# RabbitMQ: 49
# Qt: 49
# Golang: 48
# CSS3: 47
# Node.js: 47
# HTML5: 46
# Работа с базами данных: 42
# jQuery: 41
# SCADA: 40
# Английский — B2 — Средне-продвинутый: 38
# VueJS: 36
# Разработка технических заданий: 36
# REST: 36
# MongoDB: 35
# Kotlin: 35
# XML: 34
# Angular: 34
# 1С: Розница: 33
# API: 32
# CI/CD: 32
# CODESYS: 31
# Базы данных: 30
# Работа с большим объемом информации: 30
# Системная интеграция: 29
# MS Visual Studio: 27
# Веб-программирование: 26
# Kubernetes: 26
# Техническая поддержка пользователей: 26
# .NET Framework: 25
# СКД: 25
# .NET Core: 25
# 1С: Управление предприятием: 25
# Английский — A1 — Начальный: 24
# Android: 24
# ERP: 23
# Delphi: 22
# Техническая поддержка: 22
# JSON: 22
# STL: 22
# Информационные технологии: 22
# Symfony: 22
# Рефакторинг кода: 21
# SOLID: 21
# Битрикс24: 21
# iOS: 21
# ARM: 21
# Конфигурационное тестирование: 20
# Spring Framework: 20
# ORACLE: 20
# Apache Kafka: 20
# Бухгалтерский учет: 20
# FastAPI: 20
# Обучение и развитие: 20
# Ethernet: 19
# MS SQL Server: 19
# Алгоритмы и структуры данных: 18
# Kafka: 18
# Redux: 17
# Swift: 17
# 1С: Бухгалтерия и склад: 17
# Ajax: 16
# Английский — A2 — Элементарный: 16
# Пуско-наладочные работы: 16
# Работа в условиях многозадачности: 16
# ASP.NET: 16
# Адаптивная верстка: 16
# Ответственность: 16
# HTTP: 16
# Nginx: 15
# TCP/IP: 15
# Умение работать в условиях многозадачности: 15
# CMake: 15
# Gitlab: 15
# Автоматизация бизнес-процессов: 15
# Django Framework: 15
# Пользователь ПК: 15
# СУБД: 15
# Автоматизация технологических процессов: 15
# MVC: 15
# Modbus: 15
# Transact-SQL: 14
# 1C: Бухгалтерия: 14
# 1С: Торговля и склад: 14
# 1С: ERP: 14
# Проектирование: 14
# Agile: 14
# Yii: 13
# Разработка инструкций: 13
# CMS Wordpress: 13
# SOAP: 13
# Схемотехника электронного оборудования: 13
# Spring Boot: 13
# Android SDK: 13
# Кроссбраузерная верстка: 13
# Администрирование сайтов: 12
# Backend: 12
# Hibernate: 12
# C: 12
# GitHub: 12
# 1C: Предприятие: 12
# 1С:ERP: 12
# JS: 12
# Bitrix: 12
# AutoCAD: 12
# Sass: 12
# Clickhouse: 12
# С#: 11
# 1C ERP: 11
# Gradle: 11
# Аналитическое мышление: 11
# Webpack: 11
# 1С: Торговля: 11
# Удаленная работа: 11
# MATLAB: 11
# STM32: 11
# Умение работать в команде: 10
# 1С: Производство: 10
# Django: 10
# Основы бухгалтерского учета: 10
# Оптимизация бизнес-процессов: 10
# Celery: 10
# Dart: 10
# Flutter: 10
# MVVM: 10
# Администрирование: 10
# Figma: 10
# Visual Studio C#: 9
# Чтение электрических схем: 9
# HTTP-сервис: 9
# WEB-сервис: 9
# GraphQL: 9
# gRPC: 9
# SVN: 9
# ASP.NET Core: 9
# Тестирование ПО: 9
# Bash: 9
# Автоматизация документооборота: 9
# 1С: УХ: 9
# Simatic WinCC flexible: 9
# 1C: Зарплата и кадры: 9
# CAN: 9
# PLK: 9
# OPC DA/ HDA/ UA: 9
# Profbus: 9
# Foundation: 9
# Yokogawa Centum VP Yokogawa ProSafe: 9
# Техническая документация: 8
# Unit Testing: 8
# WPF: 8
# Управление проектами: 8
# Микросервисная архитектура: 8
# JSON API: 8
# Разработка 1С: 8
# ePLAN: 8
# Vue: 8
# Unity: 8
# Grafana: 8
# DDD: 8
# Vue.js: 8
# SQLAlchemy: 8
# КИПиА: 8
# RTOS: 8
# Atlassian Jira: 8
# PHP5: 8
# Frontend: 7
# Русский — C1 — Продвинутый: 7
# Автоматизация учета: 7
# VHDL: 7
# Docker-compose: 7
# Ruby On Rails: 7
# Xcode: 7
# LINQ: 7
# ПЛИС: 7
# SPI: 7
# USB: 7
# HTTPS: 7
# MS Office: 7
# ПЛК: 7
# CMS: 7
# Boost: 7
# Entity Framework: 7
# 1С: Предприятие: Бухгалтерский Учет: 7
# БСП: 7
# SQLite: 7
# React Native: 7
# Администрирование серверов Windows: 6
# Ремонт ПК: 6
# Cистемы управления базами данных: 6
# MS Dos: 6
# Jira: 6
# Функциональное тестирование: 6
# Основы баз данных: 6
# Pascal: 6
# 1С: Предприятие: Розница: 6
# ReactJS: 6
# Проектная документация: 6
# Знание технологических процессов: 6
# FBD: 6
# Электрические системы и слаботочные системы: 6
# Релейная защита и автоматика: 6
# промышленные сети: 6
# BACnet: 6
# Разработка эксплуатационной документации: 6
# Многозадачность: 6
# GIS: 6
# MS Excel: 6
# RxJava: 6
# Zabbix: 6
# BPMN: 6
# Power BI: 6
# Flask: 6
# DevOps: 6
# AWS: 6
# ML: 6
# Организаторские навыки: 6
# UIKit: 6
# Контроллеры: 6
# Java Script: 6
# Adobe Photoshop: 6
# Управленческий учет: 6
# Libvirt: 6
# Sanlock: 6
# 1C: Финансы: 6
# Автоматизация: 6
# Go: 6
# Электронный документооборот: 6
# 1С: Склад: 6
# 1С БГУ: 6
# FPGA: 6
# программист: 6
# SCSS: 6
# Постановка задач разработчикам: 6
# Firebase: 6
# Анализ данных: 5
# Design Patterns: 5
# Верстка: 5
# Atlassian Confluence: 5
# Умение слушать: 5
# GitLab CI: 5
# Знание 1С: 5
# АСУ: 5
# Системное тестирование: 5
# способность анализировать проблемы, эффективно искать пути их разрешения: 5
# Verilog HDL: 5
# САПР: 5
# Multithread Programming: 5
# СБИС: 5
# 1С: УСН: 5
# Django Rest Framework: 5
# Основы налогового учета: 5
# МЭК 61131-3: 5
# Objective-C: 5
# Системный анализ: 5
# Apache HTTP Server: 5
# Администрирование серверов Linux: 5
# WCF: 5
# Apache Maven: 5
# Oracle Pl/SQL: 5
# Администрирование серверов: 5
# Системы контроля версий: 5
# Бизнес-анализ: 5
# Анализ требований: 5
# Wireshark: 5
# парсинг: 5
# Bootstrap: 5
# CRM: 5
# Готовность обучаться: 5
# Ориентация на результат: 5
# Разработка проектной документации: 5
# HMI: 5
# OpenCV: 5
# KNX: 5
# MES: 5
# Коммуникабельность: 5
# Основы программирования: 5
# Технический склад ума: 5
# Внимательность, ответственность: 5
# Elasticsearch: 5
# RS232/RS485: 5
# Битрикс 24: 5
# Математическое программирование: 5
# Siemens: 5
# TIA Portal: 5
# Моделирование бизнес-процессов: 5
# Аналитический склад ума: 5
# 1С: ЗУП 2.5: 5
# 1С: ЗУП 3.1: 5
# Разработка на платформе «1С: Предприятие 8.3»: 5
# Сопровождение 1С: ЗУП: 5
# Развитие 1С: ЗУП: 5
# Администрирование сетевого оборудования: 4
# Точность и внимательность к деталям: 4
# Поиск информации в интернет: 4
# Обучение пользователей: 4
# ГОСТ: 4
# DMA: 4
# GSM: 4
# NET: 4
# Clean Architecture: 4
# Высшее образование: 4
# Web: 4
# Управление бухгалтерией: 4
# Программирование: 4
# Unix: 4
# Altium Designer: 4
# Vivado: 4
# ЕСКД: 4
# Тестирование баз данных: 4
# ОВЕН: 4
# Mathcad: 4
# Русский — C2 — В совершенстве: 4
# Hibernate ORM: 4
# Ruby: 4
# iOS SDK: 4
# bitrix: 4
# D7: 4
# Langchain: 4
# LangGraph: 4
# WebRTC: 4
# Исполнительность: 4
# Математический склад ума: 4
# UART: 4
# База данных: Oracle: 4
# Разработка бизнес-требований: 4
# Разработка функциональных требований: 4
# aiohttp: 4
# MVP: 4
# Scrum: 4
# Spring: 4
# NoSQL: 4
# Less: 4
# ETL: 4
# микроконтроллеры: 4
# Wordpress: 4
# Серверное оборудование: 4
# STM: 4
# Android Studio: 4
# Анализ кода: 4
# PLC: 4
# OPC: 4
# CAD: 4
# Работа с http/web-сервисами: 4
# Windows 7: 3
# Компьютер: 3
# Знание компьютера: 3
# Навыки составления отчетности: 3
# Написание инструкций: 3
# IDE Lazarus: 3
# Разработка программного обеспечения для Linux: 3
# Разработка программного обеспечения для Windows: 3
# Luo: 3
# Кроссбраузерное тестирование: 3
# Sanity-тестирование: 3
# 1С: Управление нашей фирмой: 3
# Терминалы Сбора Данных: 3
# 1C Предприятие: 3
# Резервное копирование: 3
# C++17/20: 3
# MS Visual C++: 3
# SDK: 3
# программные средства сетевой передачи: 3
# SDK#: 3
# SDK сетевого протокола: 3
# PL/pgSQL: 3
# Навыки презентации: 3
# знание 1C ERP 8: 3
# Протокол Modbus: 3
# Ethernet, SDH/PDH, DDR.: 3
# SystemVerilog, Quartus, Vivado: 3
# цифровая обработка сигналов: 3
# vue.js: 3
# Электроника: 3
# NI Multisim: 3
# QT5+: 3
# Server Side Apps: 3
# web api: 3
# Windows Forms: 3
# ККМ: 3
# банковский терминал: 3
# разработка модулей: 3
# Win32 Api: 3
# Деловая коммуникация: 3
# CodeBlocks: 3
# VisualStudio: 3
# RS-485: 3
# SpiceWire: 3
# code style: 3
# Waterfall: 3
# ПО космического аппарата: 3
# PCS7: 3
# Wirenboard: 3
# 1С: Управление персоналом: 3
# Perl: 3
# Грамотная речь: 3
# Асинхронное программирование: 3
# Аналитика: 3
# Работа с людьми: 3
# Консультирование: 3
# Проведение презентаций: 3
# Simulink: 3
# Коммуникативные навыки: 3
# Spring Data: 3
# ROS: 3
# Unreal Engine: 3
# Ответственный подход к работе: 3
# Работа в коллективе: 3
# разработка программ: 3
# ABAP: 3
# Dagger2: 3
# PhpStorm: 3
# ИТ-инфраструктура: 3
# No-code: 3
# Low-code: 3
# Qt 5+: 3
# Разработка драйверов устройств для Windows: 3
# WDM: 3
# WDF: 3
# Kernel Mode: 3
# DDK/WDK: 3
# WinDbg: 3
# Перехват функций API (Hooking): 3
# Низкоуровневое программирование: 3
# x86/x64: 3
# Visual Studio Debugger: 3
# IDA Pro: 3
# VirtualBox: 3
# VMware: 3
# QEMU: 3
# Mobile Apps: 3
# nest: 3
# Kibana: 3
# ЭЦП: 3
# Active Directory: 3
# КриптоПро: 3
# ОС Windows: 3
# глубокое знание конфигураций 1с:ЗУП, 1с:ERP и БСП;: 3
# опыт написания правил конвертации, обработок, отчетов, сложных запросов;: 3
# знание предметных областей: бух.учет, управленческий учет, планирование производства;: 3
# знание предметных областей: бюджетирование, расчет и начисление ЗП, управление персоналом;: 3
# опыт командной разработки;: 3
# Информационная безопасность: 3
# Разработка нового продукта: 3
# ES6: 3
# Cortex-M: 3
# Уверенный пользователь ПК: 3
# Самообучение: 3
# способность быстро обучаться и легко воспринимать крупные объемы информации: 3
# Умение управлять временем: 3
# Умение быстро усваивать новую информацию: 3
# Умение работать с большим количеством информации: 3
# hmi: 3
# промышленные работы: 3
# разработка технических решений: 3
# DRY: 3
# KISS: 3
# CentOS: 3
# ПНР: 3
# Программное обеспечение: 3
# Структурные схемы: 3
# Принципиальные схемы: 3
# UPD: 3
# GeoDjango: 3
# CeleryBeat: 3
# PostGIS: 3
# Shapely: 3
# Code review: 3
# PgBouncer: 3
# GDAL: 3
# Mapnik: 3
# KML: 3
# ESRI Shapefile: 3
# GeoJSON: 3
# QGIS: 3
# HTML/CSS: 3
# MODX: 3
# SEO: 3
# CMS Bitrix: 3
# HTML-верстка: 3
# Embedded: 3
# Joomla CMS: 3
# CMS 1C-Битрикс: 3
# Apache Airflow: 3
# Работа с компьютером: 3
# Scrapy: 3
# NextJS: 3
# 1С Бухгалтерия КОРП: 3
# 1С ЗУП Корп: 3
# ЗУП: 3
# разработка: 3
# разработчик: 3
# Subversion: 3
# Технические задания: 3
# Моделирование бизнес процессов: 3
# Робототехника: 3
# TMS Systems: 3
# ESP 32: 3
# Локальные сети: 3
# знание 1с: 3
# Опытный пользователь ПК: 3
# Знание программы 1С: 3
# Инженерная инфраструктура и сети: 3
# Crestron: 3
# dbf: 3
# MDC: 3
# Тестирование и отладка кода: 3
# Доработка типовых конфигураций: 3
# Интеграция 1С: 3
# Интеграция и обмен с внешними системами: 3
# Отчётность о результатах разработки: 3
# Сборка приложения: 3
# CubelDE: 3
# Администрирование ОС: 3
# Администрирование баз данных: 3
# Автоматизированное тестирование: 3
# DSL: 3
# компиляторы: 3
# генерация кода: 3
# Умение организовать работу: 3
# Уверенное владение современным Delphi: 3
# Умение работать с потоками, критическими секциями, примитивами синхронизации (например, Mutex): 3
# Опыт работы с одной из СУБД: MS SQL, MySQL, SQLite, PostgreSQL, Firebird: 3
# SQL Server Profiler: 3
# Программирование 1С: 3
# Базовые знания 1С: 3
# Конфигурирование 1С: 3
# Печатные формы: 3
# программист 1С: 3
# сопровождение 1с: 3
# Memcached: 3
# Клиент-серверная архитектура: 3
# VSCode: 3
# Умение принимать решения: 3
# Доработка конфигураций: 3
# XDTO: 3
# Avalonia: 3
# Xilinx Zynq: 3
# embedded С: 3
# DMA, DDR, Ethernet: 3
# MIMO: 3
# OFDM: 3
# • программирование Ladder, ST: 3
# • КИПиА: 3
# • Английский язык: 3
# Промышленные микроконтроллеры: 3
# Обращение с технической документацией: 3
# Flex: 3
# Keil MDK: 3
# STM32CubeIDE: 3
# ESP32: 3
# микроконтроллеров семейств ARM Cortex Mx: 3
# Конвертация данных: 3
# Nuxt: 3
# Разработка расширений: 3
# Интеграция ЭДО: 3
# Обновления программ 1С: 3
# React JS: 3
# MaterialUI: 3
# Mobx: 3
# Asyncio: 3
# AIOHTTP: 3
# Cassandra: 3
# Vue.JS: 3
# ELMA: 3
# Back-end: 3
# Asio: 3
# Spirit: 3
# TDD: 3
# UI: 3
# I2C: 3
# Linux Debian: 3
# Bitrix24: 3
# CRM Битрикс 24: 3
# SolidWorks: 3
# Spring Cloud: 3
# Наполнение контентом: 3
# Buildroot Yocto TCP/IP BMC ARM Cortex Системное программирование: 3
# Azure: 3
# step7: 3
# opc: 3
# AstraRegul: 3
# 1С:УТ: 3
# Клиенториентированность: 3
# Внимание к деталям: 3
# Assembler: 3
# Hardware: 3
# PHPUnit: 3
# Станки ЧПУ: 3
# Чтение чертежей: 3
# POSIX: 3
# Интеграция программных модулей: 3
# VB: 3
# Бухгалтерская отчетность: 3
# Основные средства: 3
# Проведение тестирований: 2
# Продвинутый пользователь ПК: 2
# CMS ModX: 2
# CMS NetCat: 2
# NXP: 2
# PowerPC: 2
# Linux Kernel:: 2
# VLAN: 2
# Make: 2
# Autotools: 2
# Gprof: 2
# gdb: 2
# LTE: 2
# WinForm: 2
# Разработка технической документации: 2
# IDE VS: 2
# legacy code: 2
# Эффективное принятие решений: 2
# Организационная осведомленность: 2
# Составление предложений о работе: 2
# УЖЦ: 2
# Систематизация информации: 2
# Микроконтроллеры: 2
# Elixir: 2
# Функциональное программирование: 2
# Программист 1 С: 2
# 1С: Бухгалтерия предприятия: 2
# PCI DSS: 2
# Пунктуальность: 2
# ISE Design Suite: 2
# Xilinx: 2
# Windows: 2
# Qt Creator: 2
# внешнее оборудование: 2
# картридеры: 2
# 1С 8.3: 2
# 1С Конвертация данных: 2
# 1С ЗУП 3.0: 2
# MasterSCADA: 2
# TraceMode: 2
# Astra Linux SE: 2
# семейство ModBus: 2
# семейство RS: 2
# OPC DA: 2
# OPC UA: 2
# OPC HDA: 2
# Web-дизайн: 2
# 1С: Управление Холдингом: 2
# Управление Холдингом: 2
# 1С Управление холдингом: 2
# 1С ЗУП: 2
# 1С:ERP (1С УПП): 2
# Критическое мышление: 2
# Java EE: 2
# Liquibase: 2
# Системное мышление: 2
# Управление временем: 2
# Сопровождение 1с: 2
# Доработка 1С: 2
# 1С:УНФ: 2
# Redmine: 2
# Scala: 2
# AkkaStream: 2
# UML: 2
# Ethers.js: 2
# Nest.js: 2
# solidity: 2
# Gulp: 2
# Xilink ISE: 2
# PCI: 2
# MII: 2
# MIL: 2
# STD-1553: 2
# PCI Express: 2
# DDR SDRAM: 2
# 100M/1G Ethernet: 2
# внутрисхемная отладка ПЛИС: 2
# реализация цифровых интерфейсов: 2
# разработка и отладка проектов ПЛИС: 2
# программирование ПЛИС: 2
# Составление отчетов: 2
# VR: 2
# Blueprint: 2
# Oculus: 2
# HTC Vive: 2
# PlayStation VR: 2
# 3D: 2
# Анимация: 2
# AR: 2
# Креативность: 2
# Анализ бизнес-процессов: 2
# VisualBasic: 2
# Java SE: 2
# Складской Учет: 2
# Bitrix framework: 2
# Быстрообучаемый: 2
# NATS: 2
# nats: 2
# Языки программирования МЭК: 2
# Производство пусконаладочных работ: 2
# Supcon: 2
# playwright: 2
# SPA: 2
# Криптография: 2
# Работа с доменами: 2
# Внутренний аудит информационных систем: 2
# ClickUp: 2
# State Management (Redux, MobX, Effector и др.): 2
# WebSocket: 2
# k8s: 2
# LLM: 2
# Prometheus: 2
# SSRS: 2
# STM 32: 2
# Язык C: 2
# UX: 2
# Узбекский — C2 — В совершенстве: 2
# OpenStack: 2
# oVirt: 2
# Apache: 2
# PHP-FPM: 2
# Apache Tomcat: 2
# Joomla: 2
# Tableau: 2
# Qlik: 2
# FineBI: 2
# Greenplum: 2
# Программирование микроконтроллеров: 2
# Желание обучаться: 2
# Компас-3D: 2
# TCP: 2
# UDP: 2
# QML: 2
# Наставничество: 2
# 1С УПП: 2
# Консультирование пользователей: 2
# чтение технической документации: 2
# ARM-микроконтроллеры: 2
# 1С8: 2
# 1С с SQL: 2
# Желание работать и развиваться: 2
# QMake: 2
# Unit-тесты: 2
# ORM: 2
# Администратор OS Linux: 2
# Администратор OS Windows: 2
# Рзработка ТЗ: 2
# Мобильность: 2
# Работа с документами: 2
# RxJS: 2
# Работа с макетами: 2
# JWT: 2
# Разработка мобильных приложений: 2
# jetpack compose: 2
# MVPC: 2
# С: 2
# Borland Delphi: 2
# .NET 8: 2
# Взаимодействие с заказчиком: 2
# Simple SCADA: 2
# Weintek: 2
# SIMATIC: 2
# PHP 8: 2
# скд: 2
# расширения: 2
# Оптимизация запросов: 2
# Diffable Data Source: 2
# Compositional Layout: 2
# IT: 2
# Автоматизация производства: 2
# IEC 61131-3: 2
# Simple-SCADA: 2
# ТСР/IP: 2
# ST: 2
# SFC: 2
# EtherCAT: 2
# CNC: 2
# ЧПУ: 2
# Сервопривод: 2
# Привод: 2
# QA: 2
# Менеджмент: 2
# User Story: 2
# Деловое общение: 2
# Веб-аналитика: 2
# Google Docs: 2
# VBA: 2
# Платформа 1С: 2
# Exposed: 2
# Intellij IDEA: 2
# знание 1С: 2
# знание типовых продуктов 1С: 2
# Nats: 2
# Металлообработка: 2
# Знание MS Office: 2
# Siemens NX: 2
# Metatrader4/5: 2
# cTrader: 2
# Биржевые шлюзы: 2
# YouTrack: 2
# Allure: 2
# Yii2: 2
# Главбух: 2
# Фармация: 2
# Cortex-M4: 2
# Sparc V8: 2
# TMR: 2
# GPIO: 2
# ADC: 2
# DAC: 2
# Eclipse: 2
# Keil: 2
# VS Code: 2
# ЕСПД: 2
# stm32f407: 2
# РНР: 2
# Работать в команде: 2
# Первичная бухгалтерская документация: 2
# 1С:Предприятие 8.3, управляемые формы: 2
# 1С ERP: 2
# TIA PORTAL: 2
# Schnieder Electric: 2
# DELTA: 2
# siemens: 2
# Промышленный протоколы связи: 2
# Step7: 2
# ASP.NET MVC: 2
# Postgres: 2
# Организация конференций: 2
# BIOS: 2
# BMC: 2
# UEFI: 2
# Websocket: 2
# Alpha.Platform (Microsoft, lunux): 2
# Wonderware SP: 2
# MasterSCADA 4D: 2
# WINCC: 2
# WinCC OA: 2
# ProfiNet: 2
# Profibus: 2
# SNMP: 2
# МЭК61850: 2
# МЭК60870: 2
# frontend: 2
# Разработка бюджетных моделей: 2
# Optimacros: 2
# Anaplan: 2
# Финансовое моделирование: 2
# SSH: 2
# yii2: 2
# 1С:ЗУП: 2
# RS-232: 2
# stm-32: 2
# kafka: 2
# Zenject: 2
# TextMeshPro: 2
# VContainer: 2
# UI Toolkit: 2
# USS: 2
# DoTween: 2
# HTTP(S): 2
# BestHttp: 2
# Applovin: 2
# AdJust: 2
# AI: 2
# Коммуникабельность, ответственность: 2
# 1С: Управление холдингом: 2
# 1С: Предприятие 8.3: 2
# Финансовая отчетность: 2
# Написание технических заданий: 2
# Роботизация: 2
# PHP 7.4-8: 1
# программное обеспечение: 1
# Описание бизнес-процессов: 1
# высшее образование: 1
# Навыки программирования в системе 1С:Предприятие 8: 1
# code-review: 1
# Web/FTP Proxy (Bluecoat SG): 1
# Математическая статистика: 1
# Развитые софт-скиллы: 1
# Желание развиваться: 1
# RTK: 1
# StyledComponents: 1
# Material: 1
# ANT: 1
# Protobuf: 1
# Olap (online analytical processing): 1
# SSIS: 1
# SSAS: 1
# Настройка сетевых подключений: 1
# Управленческие навыки: 1
# Бюджетирование: 1
# Аналитические способности: 1
# MS Project: 1
# MS Visio: 1
# MS Word: 1
# средства связи: 1
# Разработка регламентов: 1
# Настройка серверов: 1
# Техническое обслуживание: 1
# Антивирусная защита сети: 1
# Организационные навыки: 1
# Управление процессами: 1
# Развертывание 1С: 1
# GitFlow: 1
# SpringBoot: 1
# GUI: 1
# Работа в 1С Предприятие: 1
# CQRS: 1
# RoadRunner: 1
# Temporal: 1
# KrakenD: 1
# Integration testing: 1
# 1С:УХ: 1
# Нетиповые конфигурации: 1
# 1С:ERPУХ: 1
# Express.js: 1
# Styled Components: 1
# Embedded linux: 1
# Английский — C1 — Продвинутый: 1
# IIS: 1
# PageSpeed: 1
# React.js: 1
# Docker/Docker compose: 1
# Python Core: 1
# Английский B1: 1
# Написание приложений: 1
# Андройд: 1
# Андройд програмист: 1
# RESTful: 1
# Retrofit: 1
# Dagger: 1
# Hibernate/JPA: 1
# Многопоточность: 1
# ООП/SOLID: 1
# Maven/Git: 1
# Работа с высоконагруженными системами: 1
# OpenShift/Kubernetes: 1
# Базовое понимание Scala: 1
# Гибкость мышления: 1
# НДФЛ: 1
# НДС: 1
# Библиотека стандартных подсистем: 1
# Тестирование API: 1
# AngularJS: 1
# Ведение документации: 1
# Работа с чертежами: 1
# OSI: 1
# XDP: 1
# DPDK: 1
# eBPF: 1
# Linux API: 1
# Yocto project: 1
# Build root: 1
# Das U-Boot: 1
# Mac Os: 1
# Oracle Forms: 1
# Oracle APEX: 1
# Oracle Data Integrator: 1
# Oracle SQL Trace: 1
# TKPROF: 1
# обычные формы: 1
# разработчик 1С: 1
# Ввод оборудования в эксплуатацию: 1
# AggreGate: 1
# Стрессоустойчивость: 1
# Перевод технической документации: 1
# elixir: 1
# Micronaut: 1
# Apache Spark: 1
# Directum: 1
# кадровый документооборот: 1
# NextJs: 1
# MasterCAM: 1
# ELK: 1
# ImGui: 1
# 1С: УНФ: 1
# SQL-запросы: 1
# App store: 1
# Google play: 1
# Feribase: 1
# Gamedev: 1
# Групповая разработка: 1
# Swagger: 1
# Terrasoft CRM: 1
# Creatio: 1
# Разработка пользовательских интерфейсов: 1
# Написание бизнес-логики: 1
# OpenDNN: 1
# OpenVino: 1
# Big Data: 1
# Коммуникация: 1
# ASP.NET Сore: 1
# Сore: 1
# Mondrian: 1
# OLAP: 1
# DevExtreme: 1
# Shell Scripting: 1
# ЦОС: 1
# Simulation: 1
# Прикладное программирование: 1
# Pytest: 1
# Инициативность: 1
# Websockets: 1
# Сопровождение ПО: 1
# Установка и настройка ПО: 1
# Умение организовать работу, планировать, принимать решения: 1
# Сетевые технологии: 1
# AVR: 1
# ESP: 1
# EasyEDA: 1
# Fusion360: 1
# Cura: 1
# PlatformIO: 1
# Raspbery pi: 1
# 1С: Предприятие: Управление строительной организацией: 1
# EDT: 1
# Telegram: 1
# Узбекский — C1 — Продвинутый: 1
# Ansible: 1
# Configuration Managemet tools: 1
# Build Automation tools: 1
# Планирование карьеры: 1
# 1с 8.3: 1
# 1С Предприятие 8.3: 1
# Казахский — C2 — В совершенстве: 1
# Активная жизненная позиция: 1
# Быстрая обучаемость: 1
# Отличное знание ПК: 1
# Умение работать в коллективе: 1
# WMS-системы: 1
# Управляемый интерфейс, 1С:Управление торговлей 8, наличие сертификатов 1С: 1
# Настройка ПК: 1
# Установка ПО: 1
# Установка драйверов: 1
# Smarteam: 1
# Клиент-сервер: 1
# OOP: 1
# Web Application Development: 1
# знание основ бухучета: 1
# 1С: Университет: 1
# Внедренец: 1
# Программист 1С: 1
# Консультант 1С: 1
# Желание учиться и развиваться: 1
# Системность: 1
# Решение проблем: 1
# Работа в режиме многозадачности: 1
# удаленная работа: 1
# 1С: УАТ: 1
# asyncio: 1
# PyTorch: 1
# pandas: 1
# Numpy: 1
# LangChain: 1
# Tilda: 1
# Эмпатия: 1
# Доброжелательность: 1
# Внимательность: 1
# Grape: 1
# C++ Builder: 1
# Техническое обслуживание инженерных систем: 1
# 1С 8.2: 1
# Продвижение сайтов: 1
# Управляемые формы: 1
# BI: 1
# приборостроение: 1
# MFC: 1
# мэк 61131-3: 1
# Нейронные сети: 1
# Machine Learning: 1
# 1С: CRM ПРОФ: 1
# Преподаватель: 1
# T-FLEX: 1
# Обеспечение качества программного обеспечения: 1
# Tarantool: 1
# Pulsar: 1
# *nix-системы: 1
# S3: 1
# PaaS: 1
# FFmpeg: 1
# ProSoft Regul R500: 1
# ISaGRAF: 1
# Step 7: 1
# PCS 7: 1
# оформление документации: 1
# Работа с ПК: 1
# Способность работать с документами: 1
# Ответственность и пунктуальность: 1
# Высокая ответственность: 1
# .Net: 1
# UI-тесты: 1
# Rxdart: 1
# Dio: 1
# 1С:Документооборот 3.0: 1
# Обучение персонала: 1
# Тестирование: 1
# MIPS: 1
# FreeRTOS: 1
